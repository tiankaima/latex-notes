# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([30.5, 40.0, 49.7, 59.6, 69.6, 79.4])
y = np.array([0.303, 0.398, 0.495, 0.594, 0.692, 0.790])
print(x, y)
# Out:
# [30.5 40.  49.7 59.6 69.6 79.4] [0.303 0.398 0.495 0.594 0.692 0.79 ]

# %%
z = np.linspace(35.0, 42.0, 15)
x = np.array([34.9, 35.7, 36.3, 36.5, 36.8, 37.3, 38.1,
              38.4, 39.0, 39.5, 40.1, 40.5, 41.1, 41.6, 42.1])
y = np.array([34.9, 35.7, 36.2, 36.5, 36.7, 37.2, 38.0,
              38.4, 39.0, 39.4, 40.2, 40.5, 41.0, 41.5, 42.0])
print(z, '\n', x1, '\n', y1)
# Out:
# [35.  35.5 36.  36.5 37.  37.5 38.  38.5 39.  39.5 40.  40.5 41.  41.5
#  42. ]
#  [34.9 35.7 36.3 36.5 36.8 37.3 38.1 38.4 39.  39.5 40.1 40.5 41.1 41.6
#  42.1]
#  [34.9 35.7 36.2 36.5 36.7 37.2 38.  38.4 39.  39.4 40.2 40.5 41.  41.5
#  42. ]

# %%
fit = np.polyfit(x, y, 1)
print(fit)
print(np.corrcoef(x,y))
# plt.plot(x, fit[0] * x + fit[1], color='red')
plt.plot(x,x,color='red')
plt.plot(x,y,color='blue')
plt.scatter(x, y)
plt.savefig('img/2.png')
# Out:
# [0.99577191 0.11622764]
# [[1.        0.9996036]
#  [0.9996036 1.       ]]

# %%
np.polyfit(y,b,1)
# Out:
# array([0.15897539, 2.55208333])
