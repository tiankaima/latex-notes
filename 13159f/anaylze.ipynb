# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
repl = """
0.03985	0.0962	0.0982	0.0998	0.1013
0.07976	0.1808	0.1844	0.1878	0.1908
0.1197	0.2561	0.2612	0.2662	0.2707
0.15967	0.3189	0.3264	0.3331	0.339
0.1996	0.3606	0.3696	0.3781	0.385
0.2395	0.3582	0.3949	0.4036	0.4114
0.27949	0.4034	0.4141	0.4236	0.4321
0.31944	0.4196	0.4308	0.4409	0.4498
0.35935	0.433	0.4448	0.4555	0.4651
0.39932	0.4464	0.4587	0.47	0.4801
0.43923	0.4596	0.4727	0.4846	0.4951
0.47915	0.4727	0.4866	0.4991	0.5101
0.51913	0.4861	0.5006	0.5136	0.5253
0.55907	0.4999	0.5151	0.5287	0.5409
0.59897	0.5138	0.5298	0.5440 	0.5567
0.63893	0.5276	0.5444	0.5596	0.573
0.67887	0.5384	0.5579	0.5756	0.589
0.71877	0.5345	0.5544	0.5723	0.5888
0.75875	0.5307	0.5507	0.5688	0.5854
0.79866	0.5625	0.5468	0.5652	0.582
"""
print(repl.replace('\t',',').replace(' ',',').replace('\n','],['))
# Out:
# ],[0.03985,0.0962,0.0982,0.0998,0.1013],[0.07976,0.1808,0.1844,0.1878,0.1908],[0.1197,0.2561,0.2612,0.2662,0.2707],[0.15967,0.3189,0.3264,0.3331,0.339],[0.1996,0.3606,0.3696,0.3781,0.385],[0.2395,0.3582,0.3949,0.4036,0.4114],[0.27949,0.4034,0.4141,0.4236,0.4321],[0.31944,0.4196,0.4308,0.4409,0.4498],[0.35935,0.433,0.4448,0.4555,0.4651],[0.39932,0.4464,0.4587,0.47,0.4801],[0.43923,0.4596,0.4727,0.4846,0.4951],[0.47915,0.4727,0.4866,0.4991,0.5101],[0.51913,0.4861,0.5006,0.5136,0.5253],[0.55907,0.4999,0.5151,0.5287,0.5409],[0.59897,0.5138,0.5298,0.5440,,0.5567],[0.63893,0.5276,0.5444,0.5596,0.573],[0.67887,0.5384,0.5579,0.5756,0.589],[0.71877,0.5345,0.5544,0.5723,0.5888],[0.75875,0.5307,0.5507,0.5688,0.5854],[0.79866,0.5625,0.5468,0.5652,0.582],[

# %%
R_0 = 327.7
k = 3500.0
IR_1 = [[0.03982, 335.7],
        [0.07974, 358.2],
        [0.11968, 388.4],
        [0.15965, 421.2],
        [0.19958, 449.2],
        [0.23948, 468.7],
        [0.27946, 486.4],
        [0.31942, 503.0],
        [0.35932, 518.3],
        [0.39930, 533.4],
        [0.43922, 549.0],
        [0.47914, 564.6],
        [0.51912, 581.3],
        [0.55906, 599.0],
        [0.59897, 617.4],
        [0.63892, 636.5],
        [0.67886, 656.7],
        [0.71877, 676.0],
        [0.75875, 694.7],
        [0.79866, 712.9]]

IR_2 = [[0.03983, 344.6],
        [0.07975, 380.4],
        [0.11968, 428.4],
        [0.15965, 479.9],
        [0.19958, 522.0],
        [0.23949, 550.3],
        [0.27947, 574.9],
        [0.31943, 597.6],
        [0.35934, 618.1],
        [0.39931, 638.8],
        [0.43923, 660.2],
        [0.47915, 681.5],
        [0.51912, 704.0],
        [0.55906, 727.3],
        [0.59897, 752.1],
        [0.63893, 778.3],
        [0.67888, 805.1],
        [0.71878, 830.4],
        [0.75876, 855.2],
        [0.79868, 883.0]]

IR_3 = [[0.03985, 0.0962, 0.0982, 0.0998, 0.1013],
        [0.07976, 0.1808, 0.1844, 0.1878, 0.1908],
        [0.1197, 0.2561, 0.2612, 0.2662, 0.2707],
        [0.15967, 0.3189, 0.3264, 0.3331, 0.339],
        [0.1996, 0.3606, 0.3696, 0.3781, 0.385],
        [0.2395, 0.3852, 0.3949, 0.4036, 0.4114],
        [0.27949, 0.4034, 0.4141, 0.4236, 0.4321],
        [0.31944, 0.4196, 0.4308, 0.4409, 0.4498],
        [0.35935, 0.433, 0.4448, 0.4555, 0.4651],
        [0.39932, 0.4464, 0.4587, 0.47, 0.4801],
        [0.43923, 0.4596, 0.4727, 0.4846, 0.4951],
        [0.47915, 0.4727, 0.4866, 0.4991, 0.5101],
        [0.51913, 0.4861, 0.5006, 0.5136, 0.5253],
        [0.55907, 0.4999, 0.5151, 0.5287, 0.5409],
        [0.59897, 0.5138, 0.5298, 0.5440, 0.5567],
        [0.63893, 0.5276, 0.5444, 0.5596, 0.573],
        [0.67887, 0.5384, 0.5579, 0.5756, 0.589],
        [0.71877, 0.5345, 0.5544, 0.5723, 0.5888],
        [0.79866, 0.5265, 0.5468, 0.5652, 0.582]]

# %%
plt.plot(np.array([x[0] for x in IR_1]) * k, np.array([x[1] for x in IR_1])/R_0, label='2&4 Disconnect')
plt.scatter(np.array([x[0] for x in IR_1]) * k, np.array([x[1] for x in IR_1])/R_0)

plt.plot(np.array([x[0] for x in IR_2]) * k, np.array([x[1] for x in IR_2])/R_0, label='2&4 Connect')
plt.scatter(np.array([x[0] for x in IR_2]) * k, np.array([x[1] for x in IR_2])/R_0)

plt.xlabel('$B(Gs)$')
plt.ylabel('$\Delta R/ R_0$')
plt.legend()
plt.savefig('img/Fig.3.png')

# %%
# loc_3 = []
# for _IR in IR_3:
#     for i in range(3):
#         loc_3.append([_IR[0],(i+1) * 100, _IR[i+1]])

# z_min = np.array([x[2] for x in loc_3]).min()
# z_max = np.array([x[2] for x in loc_3]).max()
# fig = plt.figure()
# # ax = fig.add_subplot(projection='3d')
# # ax.scatter([x[0] for x in loc_3],[x[1] for x in loc_3],[x[2] for x in loc_3])
# ax = fig.add_subplot()
# ax.pcolormesh([x[0] for x in loc_3],[x[1] for x in loc_3],[x[2] for x in loc_3],cmap='RdBu', vmin=z_min, vmax=z_max)

# %%
p = []
R = [1/100, 1/200, 1/300, 1/400]
for _IR in IR_3:
# _IR = IR_3[0]
# if True:
    E = np.array([1/_IR[x+1] for x in range(4)])
    # print(R,E)
    kp = np.polyfit(R, E, 1)
    # plt.plot(R, E, 'o')
    # print(k)
    p.append([_IR[0], kp[0]/kp[1]])

plt.plot(np.array([x[0] for x in p]) * k, np.array([x[1] for x in p])/p[0][1], label = '2-4')
plt.scatter(np.array([x[0] for x in p]) * k, np.array([x[1] for x in p])/p[0][1])
plt.xlabel('$B(Gs)$')
plt.ylabel('$\Delta R/ R_0$')
plt.legend()
plt.savefig('img/Fig.4.png')
